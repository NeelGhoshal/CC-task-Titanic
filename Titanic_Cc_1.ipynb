# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dftr=pd.read_csv("titanic_train.csv")  #training dataset
dfte=pd.read_csv("titanic_tested.csv")

# %%
dftr
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
dfte
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
df=pd.concat([dftr,dfte]) #full dataframe
df
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0              1         0       3  ...    7.2500   NaN         S
# 1              2         1       1  ...   71.2833   C85         C
# 2              3         1       3  ...    7.9250   NaN         S
# 3              4         1       1  ...   53.1000  C123         S
# 4              5         0       3  ...    8.0500   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [1309 rows x 12 columns]

# %%
s1=df['Survived'].sum()
s1  
s2=1309-s1
values=[s1,s2]
labels=["Those who survived","Those who didnt"]
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8e8224f290>,
# ...
#  [Text(0.4133180308811586, 1.0193960002611948, 'Those who survived'),
#   Text(-0.4133181263238983, -1.0193959615635635, 'Those who didnt')])

# %%
df.isnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0        False     False   False  False  ...   False  False   True     False
# 1        False     False   False  False  ...   False  False  False     False
# 2        False     False   False  False  ...   False  False   True     False
# 3        False     False   False  False  ...   False  False  False     False
# 4        False     False   False  False  ...   False  False   True     False
#
# [5 rows x 12 columns]

# %%
df.isnull().sum()   #we can observe that a lot of cabin data is missing
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df=df.drop(['Cabin'],axis='columns')  #removing cabin column
df
# Out:
#      PassengerId  Survived  Pclass  ...              Ticket      Fare  Embarked
# 0              1         0       3  ...           A/5 21171    7.2500         S
# 1              2         1       1  ...            PC 17599   71.2833         C
# 2              3         1       3  ...    STON/O2. 3101282    7.9250         S
# 3              4         1       1  ...              113803   53.1000         S
# 4              5         0       3  ...              373450    8.0500         S
# ..           ...       ...     ...  ...                 ...       ...       ...
# 413         1305         0       3  ...           A.5. 3236    8.0500         S
# 414         1306         1       1  ...            PC 17758  108.9000         C
# 415         1307         0       3  ...  SOTON/O.Q. 3101262    7.2500         S
# 416         1308         0       3  ...              359309    8.0500         S
# 417         1309         0       3  ...                2668   22.3583         C
#
# ...

# %%
plt.bar(df['Age']+0.2,df['Survived']==1,width=0.2,color='g') #surviving probability
plt.bar(df['Age']-0.2,df['Survived']==0,width=0.2,color='b')
# Out:
# <BarContainer object of 1309 artists>

# %%
df['Age'].isnull().sum()
# Out:
# 263

# %%
df['Age'].mean()
# Out:
# 29.881137667304014

# %%
df['Age'].replace(np.NaN,df['Age'].mean()).head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...              Ticket      Fare  Embarked
# 0              1         0       3  ...           A/5 21171    7.2500         S
# 1              2         1       1  ...            PC 17599   71.2833         C
# 2              3         1       3  ...    STON/O2. 3101282    7.9250         S
# 3              4         1       1  ...              113803   53.1000         S
# 4              5         0       3  ...              373450    8.0500         S
# ..           ...       ...     ...  ...                 ...       ...       ...
# 413         1305         0       3  ...           A.5. 3236    8.0500         S
# 414         1306         1       1  ...            PC 17758  108.9000         C
# 415         1307         0       3  ...  SOTON/O.Q. 3101262    7.2500         S
# 416         1308         0       3  ...              359309    8.0500         S
# 417         1309         0       3  ...                2668   22.3583         C
#
# ...

# %%
dummies2=pd.get_dummies(df.Embarked) #applying onehotencoding
dummies2
final=pd.concat([df,dummies2],axis='columns')
final=final.drop(['Embarked'],axis='columns')
final=final.drop(['Sex'],axis='columns')
final
# Out:
#      PassengerId  Survived  Pclass  ...  C  Q  S
# 0              1         0       3  ...  0  0  1
# 1              2         1       1  ...  1  0  0
# 2              3         1       3  ...  0  0  1
# 3              4         1       1  ...  0  0  1
# 4              5         0       3  ...  0  0  1
# ..           ...       ...     ...  ... .. .. ..
# 413         1305         0       3  ...  0  0  1
# 414         1306         1       1  ...  1  0  0
# 415         1307         0       3  ...  0  0  1
# 416         1308         0       3  ...  0  0  1
# 417         1309         0       3  ...  1  0  0
#
# [1309 rows x 12 columns]

# %%
dummies1=pd.get_dummies(df.Sex) #applying onehotencoding
final=pd.concat([final,dummies1],axis='columns')
final=final.drop(['Name','Ticket','Fare'], axis='columns') #preprocessed full dataset
#final=final.dropna(inplace=True) 
final
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  C  Q  S  female  male
# 0              1         0       3  22.0      1      0  0  0  1       0     1
# 1              2         1       1  38.0      1      0  1  0  0       1     0
# 2              3         1       3  26.0      0      0  0  0  1       1     0
# 3              4         1       1  35.0      1      0  0  0  1       1     0
# 4              5         0       3  35.0      0      0  0  0  1       0     1
# ..           ...       ...     ...   ...    ...    ... .. .. ..     ...   ...
# 413         1305         0       3   NaN      0      0  0  0  1       0     1
# 414         1306         1       1  39.0      0      0  1  0  0       1     0
# 415         1307         0       3  38.5      0      0  0  0  1       0     1
# 416         1308         0       3   NaN      0      0  0  0  1       0     1
# 417         1309         0       3   NaN      1      1  1  0  0       0     1
#
# [1309 rows x 11 columns]

# %%
m=dummies1.male.sum()  #total males
f=dummies1.female.sum()
v=[m,f]
l=['Total males on board','Total females on board']
plt.pie(v,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8e80542cd0>,
# ...
#  [Text(-0.48083677220945115, 0.9893411941747885, 'Total males on board'),
#   Text(0.48083667958064136, -0.9893412391939718, 'Total females on board')])

# %%
# for those who survived
dfs=final.loc[df['Survived']== 1]
dfs
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  C  Q  S  female  male
# 1              2         1       1  38.0      1      0  1  0  0       1     0
# 2              3         1       3  26.0      0      0  0  0  1       1     0
# 3              4         1       1  35.0      1      0  0  0  1       1     0
# 8              9         1       3  27.0      0      2  0  0  1       1     0
# 9             10         1       2  14.0      1      0  1  0  0       1     0
# ..           ...       ...     ...   ...    ...    ... .. .. ..     ...   ...
# 409         1301         1       3   3.0      1      1  0  0  1       1     0
# 410         1302         1       3   NaN      0      0  0  1  0       1     0
# 411         1303         1       1  37.0      1      0  0  1  0       1     0
# 412         1304         1       3  28.0      0      0  0  0  1       1     0
# 414         1306         1       1  39.0      0      0  1  0  0       1     0
#
# [494 rows x 11 columns]

# %%
m=dfs.male.sum()
f=dfs.female.sum()
v=[m,f]
l=['Total males who survived','Total females who survived']
plt.pie(v,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8e80468fd0>,
# ...
#  [Text(0.846135924957039, 0.7028897470422344, 'Total males who survived'),
#   Text(-0.8461358920523941, -0.702889786652715, 'Total females who survived')])

# %%
final=final.dropna() #removing age values that are na which are very less anyways
from sklearn.model_selection import train_test_split
x=final.drop('Survived',axis=1)

y=final['Survived']


x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train
# Out:
#      PassengerId  Pclass    Age  SibSp  Parch  C  Q  S  female  male
# 250         1142       2   0.92      1      2  0  0  1       1     0
# 407         1299       1  50.00      1      1  1  0  0       0     1
# 743          744       3  24.00      1      0  0  0  1       0     1
# 847          848       3  35.00      0      0  1  0  0       0     1
# 206         1098       3  35.00      0      0  0  1  0       1     0
# ..           ...     ...    ...    ...    ... .. .. ..     ...   ...
# 617          618       3  26.00      1      0  0  0  1       1     0
# 379          380       3  19.00      0      0  0  0  1       0     1
# 216          217       3  27.00      0      0  0  0  1       1     0
# 52           944       2  20.00      2      1  0  0  1       1     0
# 122         1014       1  35.00      1      0  1  0  0       1     0
#
# [784 rows x 10 columns]

# %%
model1.fit(x_train,y_train)
model1.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.851145038167939

# %%
from sklearn import tree
model2=tree.DecisionTreeClassifier()
model2.fit(x_train,y_train)
model2.score(x_test,y_test)
# Out:
# 0.8129770992366412

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier() 
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8549618320610687

# %%
from sklearn.svm import SVC
model=SVC() 
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6259541984732825

# %%
#Random forest classifier is currently the best model to use here
